# %% [markdown]
# ### Deep Learning - Dr. Xingquan (Hill) Zhu
# ### Assignment 3
# ### Hsin Ting Ho (Z#23500922)

# %% [markdown]
# #### Question 1 [1 pt]
# ![image.png](attachment:image.png)
# #### Figure 1 shows a sample dataset with three types of instances (rectangles, diamonds, and circles). The instances are also color coded (each color denotes one type of instances). Each instance has two feature dimensions (X1 and X2) as shown in Figure 1. Please design a neural network to correctly classify instances into groups (Only design the network structure. No need to find correct weight values)

# %% [markdown]
# * Please show your network (including input layer, hidden layer(s), and output layers). Please show correct input dimensions and number of nodes ofeach layers [0.5 pt]
# >

# %% [markdown]
# * Explain the functionality of each hidden layers. Explain why do you choose a certain number hidden nodes and output nodes? [0.5 pt]
# >

# %% [markdown]
# #### Question 2[1 pt]
# ![image.png](attachment:image.png)
# #### Figure 2 shows three neural network structures. (a) is a single layer neural network, (b) is a one hidden layer neural network, and (c) is atwo hidden layer neural network, where each rectangle box denotes a one hidden layer network similar to (b).

# %% [markdown]
# * Please draw decision regions for each network, respectively [0.5 pt],
# >

# %% [markdown]
# * Explain how the networks learn to classify samples into different categories [0.5 pt]
# >

# %% [markdown]
# #### Question 3[1pt]: Please derive Backpropagation weight update rules for a neural network with one hidden layer and one output layer (please show BP rules for both hidden nodes and output nodes). (You can borrow derivations in the course lectures, but please add detailed explanations)

# %% [markdown]
# #### Question 4[1.5pts]:
# ![image.png](attachment:image.png)
# #### In Figure 3, a one hidden layer neural network is trained to predict an input as “dog”or “cat”.For each input, if the label of the input is “dog”, its output from node “e”is expected to be 1, otherwise the output is expected to be 0. Similarly, if the label of the input is “Cat”, its output from node “f”is expected to be 0, otherwise the output from node “f” is 0 (using sigmoid activation function, and parametera=1).Given an input [x0, x1, x2]=[1,0.5,0.5] which is labeled as “dog”, where x0 denotes bias,

# %% [markdown]
# * please calculate its actual output from node “e”and “f”, respectively. [0.5 pt]
# >

# %% [markdown]
# * Please calculate network error of the instance.[0.5 pt]
# >

# %% [markdown]
# * Please calculate local gradient of the instance with respect to node “e”and “f”, respectively. [0.5 pt]
# >

# %% [markdown]
# #### Question 5[2pts]:
# ![image-3.png](attachment:image-3.png)
# #### Given the following feedforward neural network with one hidden layer and one output layer, assuming the network initial weights are
# ![image-2.png](attachment:image-2.png)
# #### All nodes use a sigmoid activation function with value a=1.0, and the learning rate  η is set to 0.1.The expected output is 1 if an instance’s class label is “True”, otherwise, the expected output is 0. Given the following three instances I1, I2, I3 which are labeled as “True”, “True”, and “False”, respectively,

# %% [markdown]
# * Please calculate actual outputs of each instance from the network? [0.5 pt]
# >

# %% [markdown]
# * What is the mean squared error of the network with respect to the three instances? [0.5 pt]
# >

# %% [markdown]
# * Assuming  instance I1 is  fed  to  the  network  to  update  the  weight,  please  update  the  network weight (using backpropogation rule)by using this instance (list major steps and results). [1.0 pt]
# >

# %% [markdown]
# #### Question 6[2pts]:
# ![image.png](attachment:image.png)
# #### Figure 5 shows a 6x6 image, and a 3x3 convolutional filter, and the weight symbols specified in the matrix(w1, w2, ...),

# %% [markdown]
# * please calculate the convolutional filter outputafterthe filter being applied to the redcolored circle (using w0 to denote bias)[0.5 pt]
# >

# %% [markdown]
# * what is the purpose of the weight values (w1, w2, ...)of the 3x3 filter? [0.5 p
# >

# %% [markdown]
# * Whenmoving the filter across the image using stride 1, what is the percentage of input shared beentwo consecutive points (horizontally or vertically) [0.5 pt]
# >

# %% [markdown]
# * What is the size of the feature map when applying the filter to the whole image? What are the factors determiningthe feature mapsize [0.5 pt]
# >

# %% [markdown]
# #### Question 7[1.5pts]:
# ![image.png](attachment:image.png)
# #### In Figure 2, the upper panel shows a convolutional filter being applied to an image with 6x6 pixels to generate output, and the lower panel shows a fully connected dense network to process the same image.

# %% [markdown]
# * For the dense network, how many neurons are needed to produce the results which are the same as the convolutional filter? How many parameters are need for the dense network?
# >

# %% [markdown]
# * How many weight values does the convolutional have?
# >

# %% [markdown]
# * Explain why the dense network is designed to find global pattern, whereas the convolutional filter is designed to find local patterns?
# >

# %% [markdown]
# #### Question 8 [2pts]
# #### The Multi-Layer NN RecognitionNotebook in the Canvas shows detailed procedures about how to use Oivetti face dataset (from AT&T) to train Neural Network classifiers for face classification. The dataset in the Canvas also provides“olivetti_faces.npy” and “olivetti_faces_target.npy”, which includes 400 faces in 40 classes (40 different person). Please implement following face recognition task using Neural Networks.

# %%
#Please show at least one face images for each class in the Oivetti face dataset100. 
#Randomly split the dataset into 60% training and 40% test samples. 
#Train a one-hidden layer neural network with 10 hidden nodes. 
#Report the classification accuracy of the classifier on the test set [1 pt]
