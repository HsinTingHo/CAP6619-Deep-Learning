# %% [markdown]
# ### Deep Learning - Dr. Xingquan (Hill) Zhu
# ### Assignment 1
# ### Hsin Ting Ho (Z#23500922)

# %% [markdown]
# #### Question 1 [2pts: 0.4/each]:
# #### Use your own language to briefly explain following concepts:
# ##### 1) Machine learning:
# > Machine learning is a problem soving approach that improve itself by analyzing training examples. Machine learning can complete tasks such as classification and numeric prediction without being explicitly programmed because algorithms enable self-learning. There are three main learning types, supervised learning, unsupervised learning, and reinforcement learning.
# ##### 2)Machine learning models:
# > Machine learning models are the outputs of machine learning algorithms that are capable of , including but not limited to, classifying and forcasting. Machine learning models are produced by feeding data to machine learning algorithms.
# ##### 3)Neural Network:
# > Neural network is a machine learning technique. A neural network is constructed by one or more layers of artificial neurons, whichs are a series of algorithms.
# ##### 4)Key difference between Rule-based systems, Classic machine learing, and Deep learning:
# > Rule-based systems do not have learning capability. It relies on explicitly programmed logics to produce output. On the other hand, classic machine learning and deep learning are capable of learning and extract patterns from data. The key difference between classic machine learning and deep learning is the construction of the model. Classic machin learning models are often constructed by a single algorithm or a collection of algorithms while deep learning modles are constructed by artificial neurons.
# ##### 5)Artificial Neuron
# > An artificial neuron is a mathmatical function that produce an output by permform caculation with the inputs and their weights. It is the most basic element of a neural network.

# %% [markdown]
# #### Question 2[1pts]
# #### Show perceptron structure and explain the function of each component, including inputs, weights, summing function, activation function, and output [1pt].
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1. Inputs(X1, X2, ..., Xm)
# >inputs are numerical values that feed into a neuron
# #### 2. b
# >b is bias which is always set to 1. Bias is adjusted with a weight before feed into summing function.
# #### 3. weights(W1, W2, ..., Wm)
# >weights are used to emphasize or to play down input values to achive a more desirable output
# #### 4. summing function
# >summing funciton sum all the products of input and its weight
# #### 5. activation function
# >activation function is an equation that transform the result of the summing function to an output.
# #### 6. output
# >output is produced by all above calculation. It can be the final result of a network or the input of another neuron

# %% [markdown]
# #### Question 3 [1.5pt].
# #### Given a set of images, please design a network (with one hidden layers) to classify images into three categories: cat, dog, others. Show network architecture, including inputs, neurons and outputs[0. 5 pt]
# >![image.png](attachment:image.png)
# #### What is the purpose of using training examples in a neural network[0.5 pt]?
# > Training examples are served as teaching materials for neurons. Neurons learn from the traning example to derive desired pattern within data.
# #### what is expected output vs. actual output of each neuron, with respect to a training sample? [0.5pt]
# >Expected output is the label of the training sample, and the actual output is the output produced by the neural network with the given traning sample.

# %% [markdown]
# #### Question 4[1pt]
# ![image-2.png](attachment:image-2.png)
# #### Figure 1 shows four activation function in the neural network, please show the mathematical formulation of each activation function [0.5], and explain the characteristics of each activation function [0.5 pt].

# %% [markdown]
# 1. (a)Step funciton
# ![Screen%20Shot%202020-09-08%20at%202.55.39%20PM.png](attachment:Screen%20Shot%202020-09-08%20at%202.55.39%20PM.png)
# > It is typical activation function for classification problems. If the local field(the result of summing function) reaches a threshold, the neuron output 1, otherwise the neuron output 0.

# %% [markdown]
# 2. (b)Sigmoid
# ![image.png](attachment:image.png)
# >Sigmoid is often used for multi-layer network. It taks local field and transform it to a number between 0 and 1.

# %% [markdown]
# 3. (c)Hyperbolic tangent
# ![image.png](attachment:image.png)
# >Hyperbolic tangent is common used for multi-layer network as well. It take local field and transform it to a number between -1 and 1.

# %% [markdown]
# 4. (d)Rectified Linear Unit (ReLU)
# ![image.png](attachment:image.png)
# > ReLU is commonly used due to its comutational efficiency and the fact that it would not cause gradient vanish. However, it is not countinuous and not bounded.

# %% [markdown]
# #### Question 5[1.5pts]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Figure 2 shows a set of samples (dots) which are labeled as red and green (red dots belong to class C2, and green dots belong to class C1). Explain how can we train a neuron to correctly classify dots into different classes (C1 vs. C2) [0.5 pt], What are the roles of the weight values of the neuron [0.5 pt], Show the decisionboundary of the learned neuron [0.5 pt]
# ![image-3.png](attachment:image-3.png)
# >We feed the neuron training samples with labels until the neuron adjusts its weights(w0,w1,w2)to formulate a equation that produces a decision boundry which can seperate C1 from C2. The weights are served as the coiffients of each corresponded feature.

# %% [markdown]
# #### Question 6[3pts]:
# #### Please download housing.header.txt dataset from Canvas, and use a programming language (Python, R, etc.)to implement following tasks (a brief description of this dataset is available from the following URL)https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html
# 1. Read housing.header.txt as a dataframe. Report number of instances and features.
# 2. Report all samples with respect to the Crim index on a plot (the x-axis showsthe index of the sample, and the y-axis shows the crim index of the sample).
# 3. Show both histogram of the Crim index and the density of the Crim index on a 1x2 frame.
# 4. Show following four scatter plots in one frame (1x4), crim-medv, Rm-medv, Age-medv,Tax-medv, and explain how are they (Crim, Rm, Age, Tax) correlated to the medium house value(Medv)
# 5. Create a subset which only includes properties with Crim less than 1 (inclusive), and Rm greater than 6 (inclusive).
# 6. Show a scatter plot between Rm and Medv (x-axis shows Rm and y-axis denote Medv), please color all properties with 7 or larger Rm values as “red”, and rest properties as “black”.
# 7. Report the pairwise correlation between every two variables (either as a matrix or as a level plot)
# 8. Please explain which variable is mostly positively correlated to Medv (medium house value), and which variable is mostly negatively correlated to Medv.
# 9. Draw scatterplots to show relationship between each attributeand Medv, respectively.
# 10. Explainhowto use scatterplots to findattributes which are positively correlated, negatively correlated, or independent of Medv, respectively.
# 11. Please create a new instance with following attributevalueCrim=1.0,Zn=0.2,Indus=6,Chas=0.1,Nox=6.5,Rm=5,Age=100,Dis=4.1,Rad=4.5,Tax=21,Ptratio=20,B=300,Lstat=12,Medv=20.5include this instance into the original dataframe, and report the number of instances and features of the new dataframe.
# 12. Create a new feature (named“Dummy”), and include the new featureinto the new dataframe as the last feature. The valuesof the Dummy feature for each instances arerandomly generated within range [0,5].

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#1. Read housing.header.txt as a dataframe. Report number of instances and features.

data = pd.read_csv('housing.header.txt')
data.head()
# Out:
#       Crim    Zn  Indus  Chas    Nox     Rm   Age     Dis  Rad  Tax  Ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  Lstat  Medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#2. Report all samples with respect to the Crim index on a plot (the x-axis shows the index of the sample, 
#   and the y-axis shows the crim index of the sample).
crim = data['Crim']
plt.plot(crim)

# %%
#3. Show both histogram of the Crim index and the density of the Crim index on a 1x2 frame.
plt.subplot(121)
#plt.hist(crim[0])
crim.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
#4. Show following four scatter plots in one frame (1x4), crim-medv, Rm-medv, Age-medv,Tax-medv, 
#   and explain how are they (Crim, Rm, Age, Tax) correlated to the medium house value(Medv)
fields = ['Crim','Rm', 'Age', 'Tax']
medv = data['Medv']
plt.figure(figsize=(16,3))
for i,f in enumerate(fields):
    plt.subplot(1,4,i+1, title=f)
    plt.scatter(data[f], medv)

# %%
#5.Create a subset which only includes properties with Crim less than 1 (inclusive), 
#. and Rm greater than 6 (inclusive).
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-76899bacbf43> in <module>
#       1 #5.Create a subset which only includes properties with Crim less than 1 (inclusive),
#       2 #. and Rm greater than 6 (inclusive).
# ----> 3 subset = data.loc[[data['Crim']<=1] and [data['Rm']>=6]]
#       4 subset
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
# ...

# %%
#6.Show a scatter plot between Rm and Medv (x-axis shows Rm and y-axis denote Medv), 
# please color all properties with 7 or larger Rm values as “red”, and rest properties as “black”.

# %%
#7.Report the pairwise correlation between every two variables (either as a matrix or as a level plot)

# %%
#8.Please explain which variable is mostly positively correlated to Medv (medium house value), 
# and which variable is mostly negatively correlated to Medv.

# %%
#9.Draw scatterplots to show relationship between each attributeand Medv, respectively.

# %%
#10.Explainhowto use scatterplots to findattributes which are positively correlated, negatively correlated, 
# or independent of Medv, respectively.

# %%
#11.Please create a new instance with following attribute value
#   Crim=1.0,Zn=0.2,Indus=6,Chas=0.1,Nox=6.5,Rm=5,Age=100,Dis=4.1,
#   Rad=4.5,Tax=21,Ptratio=20,B=300,Lstat=12,Medv=20.5
# include this instance into the original dataframe, and report the number of instances and features of the new dataframe.

# %%
#12.Create a new feature (named“Dummy”), and include the new featureinto the new dataframe as the last feature. 
#The valuesof the Dummy feature for each instances arerandomly generated within range [0,5].
